# %%
# Import required packages
# %matplotlib notebook
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation

# %%
# Edit plot parameters
mpl.rcParams['font.family'] = 'Avenir'
mpl.rcParams['font.size'] = 18

mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.bottom'] = False

# %%
# Define the Lissajous function
def lissajous(a, b, t):
    x = np.sin(a*t)
    y = np.sin(b*t)
    return x, y

# %%
# Create figure and add axes
fig = plt.figure(figsize=(3, 3))
ax = fig.add_subplot(111)

# Create an empty plot with variable reference
l_j, = ax.plot([], [], linewidth=2.5)

# Define range shift at each timestep
range_shift = 8*np.pi

# Animation function that updates the data
def animate(i):
    t = np.arange(0 + range_shift*i, range_shift*(1 + i), 0.01)
    x, y = lissajous(2, 1, t)
    l_j.set_data(x, y)

# Use FuncAnimation to animate figure
ani = FuncAnimation(fig=fig, func=animate, frames=range(10), interval=100, repeat=True)

# Set axis limits and remove tick marks
ax.set(xlabel='a = 2\nb = 1', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))

# Make sure animation is fully visible
plt.tight_layout()

# Save and show animation
ani.save('Lissajous_1_1.gif', writer='pillow', fps=10)

# Show animation
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="300">

# %%
# Create plots and subplots
fig = plt.figure(figsize=(5, 10))
ax = fig.add_subplot(421)
ax2 = fig.add_subplot(422)
ax3 = fig.add_subplot(423)
ax4 = fig.add_subplot(424)
ax5 = fig.add_subplot(425)
ax6 = fig.add_subplot(426)
ax7 = fig.add_subplot(427)
ax8 = fig.add_subplot(428)


l_j, = ax.plot([], [], linewidth=2.5)
l_j2, = ax2.plot([], [], linewidth=2.5)
l_j3, = ax3.plot([], [], linewidth=2.5)
l_j4, = ax4.plot([], [], linewidth=2.5)
l_j5, = ax5.plot([], [], linewidth=2.5)
l_j6, = ax6.plot([], [], linewidth=2.5)
l_j7, = ax7.plot([], [], linewidth=2.5)
l_j8, = ax8.plot([], [], linewidth=2.5)

# Define range shift at each timestep
range_shift = 8*np.pi

def animate(i):
    t = np.arange(0 + range_shift*i, range_shift*(1 + i), 0.01)
    
    x, y = lissajous(1, 1, t)
    l_j.set_data(x, y)
    
    x, y = lissajous(9, 8, t)
    l_j2.set_data(x, y)
    
    x, y = lissajous(81, 64, t)
    l_j3.set_data(x, y)
    
    x, y = lissajous(4, 3, t)
    l_j4.set_data(x, y)
    
    x, y = lissajous(3, 2, t)
    l_j5.set_data(x, y)
    
    x, y = lissajous(27, 16, t)
    l_j6.set_data(x, y)
    
    x, y = lissajous(243, 128, t)
    l_j7.set_data(x, y)
    
    x, y = lissajous(2, 1, t)
    l_j8.set_data(x, y)

ani = FuncAnimation(fig=fig, func=animate, frames=range(10), interval=100, repeat=True)
ax.set(xlabel='Root', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))
ax2.set(xlabel='Major 2nd', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))
ax3.set(xlabel='Major 3rd', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))
ax4.set(xlabel='Perfect 4th', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))
ax5.set(xlabel='Perfect 5th', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))
ax6.set(xlabel='Major 6th', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))
ax7.set(xlabel='Major 7th', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))
ax8.set(xlabel='Octave', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))

# Make sure animation is fully visible
plt.tight_layout()

# Save and show animation
ani.save('Lissajous_PT.gif', writer='pillow', dpi=300, fps=10)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
# Create plots and subplots
fig = plt.figure(figsize=(5, 10))
ax = fig.add_subplot(421)
ax2 = fig.add_subplot(422)
ax3 = fig.add_subplot(423)
ax4 = fig.add_subplot(424)
ax5 = fig.add_subplot(425)
ax6 = fig.add_subplot(426)
ax7 = fig.add_subplot(427)
ax8 = fig.add_subplot(428)


l_j, = ax.plot([], [], linewidth=2.5)
l_j2, = ax2.plot([], [], linewidth=2.5)
l_j3, = ax3.plot([], [], linewidth=2.5)
l_j4, = ax4.plot([], [], linewidth=2.5)
l_j5, = ax5.plot([], [], linewidth=2.5)
l_j6, = ax6.plot([], [], linewidth=2.5)
l_j7, = ax7.plot([], [], linewidth=2.5)
l_j8, = ax8.plot([], [], linewidth=2.5)

# Define range shift at each timestep
range_shift = 8*np.pi

def animate(i):
    t = np.arange(0 + range_shift*i, range_shift*(1 + i), 0.01)
    
    x, y = lissajous(1, 1, t)
    l_j.set_data(x, y)
    
    x, y = lissajous((2**(2/12)), 1, t)
    l_j2.set_data(x, y)
    
    x, y = lissajous((2**(4/12)), 1, t)
    l_j3.set_data(x, y)
    
    x, y = lissajous((2**(5/12)), 1, t)
    l_j4.set_data(x, y)
    
    x, y = lissajous((2**(7/12)), 1, t)
    l_j5.set_data(x, y)
    
    x, y = lissajous((2**(9/12)), 1, t)
    l_j6.set_data(x, y)
    
    x, y = lissajous((2**(11/12)), 1, t)
    l_j7.set_data(x, y)
    
    x, y = lissajous(2, 1, t)
    l_j8.set_data(x, y)

ani = FuncAnimation(fig=fig, func=animate, frames=range(10), interval=100, repeat=True)
ax.set(xlabel='Root', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))
ax2.set(xlabel='Major 2nd', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))
ax3.set(xlabel='Major 3rd', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))
ax4.set(xlabel='Major 4th', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))
ax5.set(xlabel='Major 5th', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))
ax6.set(xlabel='Major 6th', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))
ax7.set(xlabel='Major 7th', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))
ax8.set(xlabel='Octave', xlim=(-1.05, 1.05), ylim=(-1.05, 1.05), xticks=([]), yticks=([]))

# Make sure animation is fully visible
plt.tight_layout()

# Save and show animation
ani.save('Lissajous_ET.gif', writer='pillow', dpi=300, fps=10)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">
